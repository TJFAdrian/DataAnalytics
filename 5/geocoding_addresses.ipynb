# %% [markdown]
# # Geocoding apartment addresses using the geoadmin API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import requests
import json
import urllib
import fnmatch
import folium
import pandas as pd
from IPython.display import clear_output

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Geocoding a single address

# %% [markdown]
# ### Define base url for address search

# %%
# Define base url for address search
base_url= "https://api3.geo.admin.ch/rest/services/api/SearchServer?"

# Set up search parameters: address, origins and type
parameters = {"searchText": "4410 Liestal, Rheinstrasse 12",
              "origins": "address",
              "type": "locations",
             }

# Urllib.parse.urlencode turns parameters into url
# print(f"{base_url}{urllib.parse.urlencode(parameters)}")

# %% [markdown]
# ### Server request & response

# %%
# Server request
r = requests.get(f"{base_url}{urllib.parse.urlencode(parameters)}")

# Get data in json-format
data = json.loads(r.content)
data

# Take only the first server response, convert to data frame with relevant infos
df = pd.DataFrame.from_dict(list(data.values())[0][0], orient='columns')
df.iloc[[1,4,5,6,11,12],:1]
# Out:
#                                          attrs
# featureId                          245015923_0
# label      Rheinstrasse 12 <b>4410 Liestal</b>
# lat                                  47.485893
# lon                                    7.73299
# x                                 259500.46875
# y                                  622185.6875

# %% [markdown]
# ## Geocoding multiple addresses

# %% [markdown]
# ### Importing apartment data

# %%
# Get current working directory
print(os.getcwd())

# Show all files in the directory
flist = fnmatch.filter(os.listdir('.'), '*.csv')
for i in flist:
    print(i)

# Read the data to a pandas data frame
df = pd.read_csv('apartments_data_prepared.csv', 
                 sep=',', 
                 encoding='utf-8')[['web-scraper-order', 
                                    'address_raw', 
                                    'datetime', 
                                    'rooms', 
                                    'area', 
                                    'luxurious', 
                                    'price_per_m2']][:100] # first 100 apartment adresses

# Get number of rows and columns
print(df.shape)

# Show first records
df.head(5)
# Out:
# C:\Users\adria\Data Analytics\5
# apartments_data_geocoded_all.csv
# apartments_data_prepared.csv
# supermarkets_data_prepared.csv
# (100, 7)
#   web-scraper-order                                 address_raw  \
# 0    1662023695-433   Sunnenbergstrasse 15, 8633 Wolfhausen, ZH
# 1    1662023745-820             Lavaterstr. 63, 8002 Zürich, ZH
# 2    1662023742-807  Langfurrenstrasse 5c, 8623 Wetzikon ZH, ZH
# 3   1662023804-1290          Sandbuckweg 5A, 8157 Dielsdorf, ZH
# 4    1662023739-771                Parkring 59, 8002 Zürich, ZH
#
#               datetime  rooms  area  luxurious  price_per_m2
# 0  2022-09-07 09:00:00    3.5   122          1         26.07
# 1  2022-09-07 09:00:00    2.5    78          0         48.21
# 2  2022-09-07 09:00:00    5.5   115          0         24.87
# 3  2022-09-07 09:00:00    3.5    74          0         29.26
# 4  2022-09-07 09:00:00    5.5   195          1         35.38

# %% [markdown]
# ### Geocoding multiple apartment addresses using the geoadmin API

# %%
# Define base url
base_url= "https://api3.geo.admin.ch/rest/services/api/SearchServer?"

# Geocode list of adresses
geolocation = []
n = 1
for i in df['address_raw'].astype(str):
    
    print('Geocoding address', 
          n, 
          'out of', 
          len(df['address_raw']), 
          ':', 
          i)
    n=n+1
    clear_output(wait=True)
    
    try:
        # Set up search parameters - address, origins and type
        parameters = {"searchText": i,
                      "origins": "address",
                      "type": "locations",
                     }

        # Server request
        r = requests.get(f"{base_url}{urllib.parse.urlencode(parameters)}")

        # Get data
        data = json.loads(r.content)

        # Take first server response, convert to df with relevant infos
        df_loc = pd.DataFrame.from_dict(list(data.values())[0][0], 
                                        orient='columns')
        geolocation.append(df_loc.iloc[[5,6],0].astype(float))
    
    except:
        geolocation.append(pd.Series(data={'lat': None, 'lon': None}))
        
        

# Write lat and lon to df
df_loc = pd.DataFrame(geolocation, 
                      columns=("lat", "lon"), 
                      index=range(len(df['address_raw'])))
df['lat'] = df_loc['lat']
df['lon'] = df_loc['lon']
df.head(5)
# Out:
#   web-scraper-order                                 address_raw  \
# 0    1662023695-433   Sunnenbergstrasse 15, 8633 Wolfhausen, ZH
# 1    1662023745-820             Lavaterstr. 63, 8002 Zürich, ZH
# 2    1662023742-807  Langfurrenstrasse 5c, 8623 Wetzikon ZH, ZH
# 3   1662023804-1290          Sandbuckweg 5A, 8157 Dielsdorf, ZH
# 4    1662023739-771                Parkring 59, 8002 Zürich, ZH
#
#               datetime  rooms  area  luxurious  price_per_m2        lat  \
# 0  2022-09-07 09:00:00    3.5   122          1         26.07  47.255714
# 1  2022-09-07 09:00:00    2.5    78          0         48.21  47.361378
# 2  2022-09-07 09:00:00    5.5   115          0         24.87  47.328632
# 3  2022-09-07 09:00:00    3.5    74          0         29.26  47.477493
# 4  2022-09-07 09:00:00    5.5   195          1         35.38  47.366898
#
#         lon
# 0  8.804976
# 1  8.533339
# 2  8.810400
# 3  8.456285
# 4  8.528817

# %% [markdown]
# ### Plot addresses on map

# %%
# Initialisierung der Map
m = folium.Map(location=[47.44, 8.65], zoom_start=10)

# Add lat/lon of addresses
df_sub = df.dropna()
for i in range(0, len(df_sub)):
    folium.Marker(location=(df_sub.iloc[i]['lat'], 
                            df_sub.iloc[i]['lon']), 
                  popup=df_sub.iloc[i]['address_raw']).add_to(m)

# Layer control
folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b13657278ffea432dbf2fddffad0e40 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b13657278ffea432dbf2fddffad0e40&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0b13657278ffea432dbf2fddffad0e40 = L.map(
#                 &quot;map_0b13657278ffea432dbf2fddffad0e40&quot;,
#                 {
#                     center: [47.44, 8.65],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_014f64c9724afa63821fb06c9cdb7c72 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0b13657278ffea432dbf2fddffad0e40);
#
#
#             var marker_bdfdd6416fdb4760a633cee88a2436e2 = L.marker(
#                 [47.255714416503906, 8.804975509643555],
#                 {}
#             ).addTo(map_0b13657278ffea432dbf2fddffad0e40);
#
#
#         var popup_0a4f6f2c6cf686df9780f562871a6ec1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b10ef4eb17b7a64df1adad888c448e13 = $(`&lt;div id=&quot;html_b10ef4eb17b7a64df1adad888c448e13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sunnenbergstrasse 15, 8633 Wolfhausen, ZH&lt;/div&gt;`)[0];
#             popup_0a4f6f2c6cf686df9780f562871a6ec1.setContent(html_b10ef4eb17b7a64df1adad888c448e13);
#
#
#         marker_bdfdd6416fdb4760a633cee88a2436e2.bindPopup(popup_0a4f6f2c6cf686df9780f562871a6ec1)
#         ;
#
#
#
#
#             var marker_9259b69605304b5da39d32e2518b91bf = L.marker(
#                 [47.36137771606445, 8.53333854675293],
#                 {}
#             ).addTo(map_0b13657278ffea432dbf2fddffad0e40);
#
#
#         var popup_1d9fab4426a00d34a23fefe9e0b581eb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_381044cb6c09cb9debc01b934caa4ded = $(`&lt;div id=&quot;html_381044cb6c09cb9debc01b934caa4ded&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lavaterstr. 63, 8002 Zürich, ZH&lt;/div&gt;`)[0];
#             popup_1d9fab4426a00d34a23fefe9e0b581eb.setContent(html_381044cb6c09cb9debc01b934caa4ded);
#
#
#         marker_9259b69605304b5da39d32e2518b91bf.bindPopup(popup_1d9fab4426a00d34a23fefe9e0b581eb)
#         ;
#
#
#
#
#             var marker_ce12aa2a6fef65752dd38267f21f525a = L.marker(
#                 [47.32863235473633, 8.810400009155273],
#                 {}
#             ).addTo(map_0b13657278ffea432dbf2fddffad0e40);
#
#
#         var popup_537904a39edd9bc3e3b764f6b8023527 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_539870edd0e209473900cef0fe554d67 = $(`&lt;div id=&quot;html_539870edd0e209473900cef0fe554d67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Langfurrenstrasse 5c, 8623 Wetzikon ZH, ZH&lt;/div&gt;`)[0];
#             popup_537904a39edd9bc3e3b764f6b8023527.setContent(html_539870edd0e209473900cef0fe554d67);
#
#
#         marker_ce12aa2a6fef65752dd38267f21f525a.bindPopup(popup_537904a39edd9bc3e3b764f6b8023527)
#         ;
#
#
#
#
#             var marker_37c78ccb87ea3bdff6397c594cf6a18f = L.marker(
#                 [47.47749328613281, 8.456284523010254],
#                 {}
#             ).addTo(map_0b13657278ffea432dbf2fddffad0e40);
#
#
#         var popup_8dd023bae7448211e59d0a3f9af9118d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4cddcd72cc135baac591583d9017bd5e = $(`&lt;div id=&quot;html_4cddcd72cc135baac591583d9017bd5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sandbuckweg 5A, 8157 Dielsdorf, ZH&lt;/div&gt;`)[0];
#             popup_8dd023bae7448211e59d0a3f9af9118d.setContent(html_4cddcd72cc135baac591583d9017bd5e);
#
#
#         marker_37c78ccb87ea3bdff6397c594cf6a18f.bindPopup(popup_8dd023bae7448211e59d0a3f9af9118d)
#         ;
#
#
#
#
#             var marker_9c9d35d3ef47ef6dcee5a26c74edbffa = L.marker(
#                 [47.36689758300781, 8.528817176818848],
#                 {}
#             ).addTo(map_0b13657278ffea432dbf2fddffad0e40);
#
#
#         var popup_6b7714e8178d34612811565e38ed38b3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_deae36d61601d97e928556e1c3df0c78 = $(`&lt;div id=&quot;html_deae36d61601d97e928556e1c3df0c78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Parkring 59, 8002 Zürich, ZH&lt;/div&gt;`)[0];
#             popup_6b7714e8178d34612811565e38ed38b3.setContent(html_deae36d61601d97e928556e1c3df0c78);
#
#
#         marker_9c9d35d3ef47ef6dcee5a26c74edbffa.bindPopup(popup_6b7714e8178d34612811565e38ed38b3)
#         ;
#
#
#
#
#             var marker_15a930a2b6fa552429faf48d82580b63 = L.marker(
#                 [47.35888671875, 8.71379566192627],
#                 {}
#             ).addTo(map_0b13657278ffea432dbf2fddffad0e40);
#
#
#         var popup_247ddd06b446009e2ed4

# %% [markdown]
# ### Save data to file

# %%
df.to_csv('apartments_data_geocoded.csv', 
           sep=",", 
           encoding='utf-8',
           index=False)

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# NT
# Windows | 10
# Datetime: 2022-10-18 10:19:37
# Python Version: 3.9.13
# -----------------------------------
