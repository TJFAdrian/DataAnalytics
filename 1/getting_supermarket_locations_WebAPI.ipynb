# %% [markdown]
# # Getting all available Swiss supermarkets using overpass Web API

# %% [markdown]
# ## Overpass turbo query to get all available supermarkets in Switzerland

# %%
from pandas import json_normalize
import requests
import json

# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["shop"="supermarket"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('supermarkets.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = json_normalize(data)
df.head(5)
# Out:
#    type        id        lat       lon tags.brand tags.brand:wikidata  \
# 0  node  33126515  47.155616  9.037915       Spar             Q610492
# 1  node  36726161  47.226191  8.980329     Migros             Q680727
# 2  node  39768209  47.225069  8.969981       Coop             Q432564
# 3  node  39947904  47.376732  8.542161       Coop             Q432564
# 4  node  48932835  47.375020  8.522895     Migros             Q680727
#
#   tags.brand:wikipedia tags.name  \
# 0   en:SPAR (retailer)      Spar
# 1            de:Migros    Migros
# 2                  NaN      Coop
# 3    de:Coop (Schweiz)      Coop
# 4            de:Migros    Migros
#
#                                   tags.opening_hours    tags.shop  ...  \
# 0  Mo-Th 08:00-19:00; Fr 08:00-20:00; Sa 08:00-17:00  supermarket  ...
# 1  Mo-Th 08:00-19:00, Fr 08:00-20:00, Sa 07:30-17...  supermarket  ...
# 2                                                NaN  supermarket  ...
# 3                                  Mo-Sa 06:00-22:00  supermarket  ...
# 4                          Mo-Sa 08:00-21:00; PH off  supermarket  ...
#
#   tags.image tags.opening_date tags.room tags.zo_area tags.addr:city:de  \
# 0        NaN               NaN       NaN          NaN               NaN
# 1        NaN               NaN       NaN          NaN               NaN
# 2        NaN               NaN       NaN          NaN               NaN
# 3        NaN               NaN       NaN          NaN               NaN
# 4        NaN               NaN       NaN          NaN               NaN
#
#   tags.addr:city:fr tags.payment:discover_card tags.trade tags.source:addr  \
# 0               NaN                        NaN        NaN              NaN
# 1               NaN                        NaN        NaN              NaN
# 2               NaN                        NaN        NaN              NaN
# 3               NaN                        NaN        NaN              NaN
# 4               NaN                        NaN        NaN              NaN
#
#   tags.postid
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 222 columns]

# %% [markdown]
# ## Plot supermarkets on map

# %%
import folium
import pandas as pd

# Subset of supermarkets by brand
locations = df[["lat", "lon", "tags.brand", "tags.shop"]].loc[df["tags.brand"] == 'Migros']
print(locations.head(5))

# Create map
map = folium.Map(location=[locations.lat.mean(), 
                           locations.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in locations.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]], 
                  popup=location_info["tags.brand"]).add_to(map)

# Plot map
map
# Out:
#           lat       lon tags.brand    tags.shop
# 1   47.226191  8.980329     Migros  supermarket
# 4   47.375020  8.522895     Migros  supermarket
# 7   47.491874  8.706448     Migros  supermarket
# 11  47.344749  8.529981     Migros  supermarket
# 16  47.375255  8.536107     Migros  supermarket
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_797ffd3d5827368e5fc3c848dc0744ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_797ffd3d5827368e5fc3c848dc0744ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_797ffd3d5827368e5fc3c848dc0744ea = L.map(
#                 &quot;map_797ffd3d5827368e5fc3c848dc0744ea&quot;,
#                 {
#                     center: [47.03287489235413, 8.00677329054326],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_797ffd3d5827368e5fc3c848dc0744ea);
#
#
#
#
#
#             var tile_layer_3ca42d36f92a29da19b37fac0121e026 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_797ffd3d5827368e5fc3c848dc0744ea);
#
#
#             var marker_089395753f0c7651b302bac719a79388 = L.marker(
#                 [47.2261912, 8.9803292],
#                 {}
#             ).addTo(map_797ffd3d5827368e5fc3c848dc0744ea);
#
#
#         var popup_bd6b53d37489bf1fb1cc7307cc1a46b2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_38f64b44040ff84f52d9feaa84659bf3 = $(`&lt;div id=&quot;html_38f64b44040ff84f52d9feaa84659bf3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#             popup_bd6b53d37489bf1fb1cc7307cc1a46b2.setContent(html_38f64b44040ff84f52d9feaa84659bf3);
#
#
#         marker_089395753f0c7651b302bac719a79388.bindPopup(popup_bd6b53d37489bf1fb1cc7307cc1a46b2)
#         ;
#
#
#
#
#             var marker_6050cb38157ed28dc85b4914a7b54515 = L.marker(
#                 [47.37502, 8.522895],
#                 {}
#             ).addTo(map_797ffd3d5827368e5fc3c848dc0744ea);
#
#
#         var popup_9ae52749d94769efbabdf6930c7c9a49 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4bcd3a24c7a446b7bae74eb7ee651b2e = $(`&lt;div id=&quot;html_4bcd3a24c7a446b7bae74eb7ee651b2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#             popup_9ae52749d94769efbabdf6930c7c9a49.setContent(html_4bcd3a24c7a446b7bae74eb7ee651b2e);
#
#
#         marker_6050cb38157ed28dc85b4914a7b54515.bindPopup(popup_9ae52749d94769efbabdf6930c7c9a49)
#         ;
#
#
#
#
#             var marker_453391e591ef321fb43738061deadb07 = L.marker(
#                 [47.4918744, 8.7064484],
#                 {}
#             ).addTo(map_797ffd3d5827368e5fc3c848dc0744ea);
#
#
#         var popup_293b3c58005f122b80c28f309f7551d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_26d7bd7374d132a8e776c0b093480974 = $(`&lt;div id=&quot;html_26d7bd7374d132a8e776c0b093480974&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#             popup_293b3c58005f122b80c28f309f7551d7.setContent(html_26d7bd7374d132a8e776c0b093480974);
#
#
#         marker_453391e591ef321fb43738061deadb07.bindPopup(popup_293b3c58005f122b80c28f309f7551d7)
#         ;
#
#
#
#
#             var marker_39a9441d5b0695756f1eb391f63c16e3 = L.marker(
#                 [47.3447487, 8.5299814],
#                 {}
#             ).addTo(map_797ffd3d5827368e5fc3c848dc0744ea);
#
#
#         var popup_a36723f66af806fe5908f0b83bb1b6ab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b0201c36722beee74b48d4d6cf1bebe7 = $(`&lt;div id=&quot;html_b0201c36722beee74b48d4d6cf1bebe7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#             popup_a36723f66af806fe5908f0b83bb1b6ab.setContent(html_b0201c36722beee74b48d4d6cf1bebe7);
#
#
#         marker_39a9441d5b0695756f1eb391f63c16e3.bindPopup(popup_a36723f66af806fe5908f0b83bb1b6ab)
#         ;
#
#
#
#
#             var marker_357eff0c0205b14e2ca549cca980dc4f = L.marker(
#                 [47.3752549, 8.5361073],
#                 {}
#             ).addTo(map_797ffd3d5827368e5fc3c848dc0744ea);
#
#
#         var popup_8e9e3e5eaffc83393655b4ec598d2cc8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_bf95bf3c7b6f0e025c982632fee47d0d = $(`&lt;div id=&quot;html_bf95bf3c7b6f0e025c982632fee47d0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#             popup_8e9e3e5eaffc83393655b4ec598d2cc8.setContent(html_bf95bf3c7b6f0e025c982632fee47d0d);
#
#
#         marker_357eff0c0205b14e2ca549cca980dc4f.bindPopup(popup_8e9e3e5eaffc83393655b4ec598d2cc8)
#         ;
#
#
#
#
#             var marker_9f55ebf318873aed96d5e98d42828e3c = L.marker(
#                 [47.2406357, 8.7239602],
#                 {}
#             ).addTo(map_797ffd3d5827368e5fc3c848dc0744ea);
#
#
#         var popup_43f648ae6b29db0e9cab66f45ad1efe8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6a8e2f2c3d2472162e5c67e385ece8e6 = $(`&l
